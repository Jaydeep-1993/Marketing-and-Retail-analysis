# %%
# Importing all the required libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
#Read Excel
#Importing the orders worksheet from Retail_dataset

orders = pd.read_excel("C://Users//Jaydeep//Downloads//Retail_dataset.xlsx", sheet_name="orders")

# %%
#Checking the length of the dimension(dataframe).
orders.shape
# Out:
# (99441, 7)

# %%
 #Checking concise summary of a dataframe.
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  datetime64[ns]
#  4   order_approved_at              99281 non-null  datetime64[ns]
#  5   order_delivered_timestamp      96476 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), object(3)
# memory usage: 5.3+ MB

# %%
#Checking the top (n) rows of the dataframe.
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_timestamp order_estimated_delivery_date
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2018-08-07 15:27:45                    2018-08-13
# ...

# %%
#Checking for the sum of duplicated values
orders.order_id.duplicated().sum()
# Out:
# 0

# %%
# Checking the counts of unique values
orders.customer_id.value_counts().sort_values(ascending=False)
# Out:
# 8d50f5eadf50201ccdcedfb9e2ac8455    17
# 3e43e6105506432c953e165fb2acf44c     9
# 1b6c7548a2a1f9037c1fd3ddfed95f33     7
# ca77025e7201e3b30c44b472ff346268     7
# 6469f99c1f9dfae7733b25662e7f1782     7
#                                     ..
# 94f3234a77f2f5b239ab74865a193724     1
# 01575c2596c13ff2422df080a71b481b     1
# 920d4709f3c3c298bdf5f08777193805     1
# e5e9da3a61436d34efc3250a52495330     1
# 71b65c569b32bbbd262f878db2b3c58d     1
# Name: customer_id, Length: 96096, dtype: int64

# %%
orders[ orders.order_status == 'delivered' ].shape
# Out:
# (96478, 7)

# %%
 orders.order_status.value_counts()
# Out:
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: order_status, dtype: int64

# %%
#checking for the percentage data frequency
orders.order_status.value_counts(normalize=True)*100
# Out:
# delivered      97.020344
# shipped         1.113223
# canceled        0.628513
# unavailable     0.612423
# invoiced        0.315765
# processing      0.302692
# created         0.005028
# approved        0.002011
# Name: order_status, dtype: float64

# %%
# Selecting the dataframe where the orders equal to "Delivered".
orders = orders[orders.order_status == 'delivered' ]
orders.shape
# Out:
# (96478, 7)

# %%
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  7c396fd4830fd04220f754e42b4e5bff
# 1  53cdb2fc8bc7dce0b6741e2150273451  af07308b275d755c9edb36a90c618231
# 2  47770eb9100c2d0c44946d9cf07ec65d  3a653a41f6f9fc3d2a113cf8398680e8
# 3  949d5b44dbf5de918fe9c16f97b45f8a  7c142cf63193a1473d2e66489a9ae977
# 4  ad21c59c0840e6cb83a9ceb5573f8159  72632f0f9dd73dfee390c9b22eb56dd6
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_timestamp order_estimated_delivery_date
# 0       2017-10-10 21:25:13                    2017-10-18
# 1       2018-08-07 15:27:45                    2018-08-13
# ...

# %%
orders.order_status.value_counts()
# Out:
# delivered    96478
# Name: order_status, dtype: int64

# %%
#Checking for the missing values.
orders.isna().sum().sort_values(ascending=False)
# Out:
# order_approved_at                14
# order_delivered_timestamp         8
# order_estimated_delivery_date     0
# order_purchase_timestamp          0
# order_status                      0
# customer_id                       0
# order_id                          0
# dtype: int64

# %%
#Replacing the value 
orders.order_approved_at.fillna(orders.order_purchase_timestamp, inplace=True)

# %%
orders.isna().sum().sort_values(ascending=False)
# Out:
# order_delivered_timestamp        8
# order_estimated_delivery_date    0
# order_approved_at                0
# order_purchase_timestamp         0
# order_status                     0
# customer_id                      0
# order_id                         0
# dtype: int64

# %%
orders.order_delivered_timestamp.fillna(orders.order_estimated_delivery_date, inplace=True)

# %%
orders.isna().sum().sort_values(ascending=False)
# Out:
# order_estimated_delivery_date    0
# order_delivered_timestamp        0
# order_approved_at                0
# order_purchase_timestamp         0
# order_status                     0
# customer_id                      0
# order_id                         0
# dtype: int64

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96478 entries, 0 to 99440
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       96478 non-null  object
#  1   customer_id                    96478 non-null  object
#  2   order_status                   96478 non-null  object
#  3   order_purchase_timestamp       96478 non-null  datetime64[ns]
#  4   order_approved_at              96478 non-null  datetime64[ns]
#  5   order_delivered_timestamp      96478 non-null  datetime64[ns]
#  6   order_estimated_delivery_date  96478 non-null  datetime64[ns]
# dtypes: datetime64[ns](4), object(3)
# memory usage: 5.9+ MB

# %%
order_items = pd.read_excel("C://Users//Jaydeep//Downloads//Retail_dataset.xlsx", sheet_name="order_items")

# %%
order_items.shape
# Out:
# (112650, 6)

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          112650 non-null  object
#  1   order_item_id     112650 non-null  int64
#  2   product_id        112650 non-null  object
#  3   seller_id         112650 non-null  object
#  4   price             112650 non-null  float64
#  5   shipping_charges  112650 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.2+ MB

# %%
order_items.isna().sum()
# Out:
# order_id            0
# order_item_id       0
# product_id          0
# seller_id           0
# price               0
# shipping_charges    0
# dtype: int64

# %%
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    shipping_charges
# 0             13.29
# 1             19.93
# 2             17.87
# 3             12.79
# 4             18.14

# %%
customers = pd.read_excel("C://Users//Jaydeep//Downloads//Retail_dataset.xlsx", sheet_name="customers")
customers.shape
# Out:
# (99441, 4)

# %%
customers.head()
# Out:
#                         customer_id  customer_zip_code_prefix  \
# 0  861eff4711a542e4b93843c6dd7febb0                     14409
# 1  290c77bc529b7ac935b93aa66c333dc3                      9790
# 2  060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3  259dac757896d24d7702b9acbbff3f3c                      8775
# 4  345ecd01c38d18a9036ed96c73b8d066                     13056
#
#            customer_city customer_state
# 0                 franca             SP
# 1  sao bernardo do campo             SP
# 2              sao paulo             SP
# 3        mogi das cruzes             SP
# 4               campinas             SP

# %%
customers.isna().sum()
# Out:
# customer_id                 0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
customers.customer_id.duplicated().sum()
# Out:
# 3345

# %%
customers[ customers.customer_id.duplicated() ]
# Out:
#                             customer_id  customer_zip_code_prefix  \
# 679    b6c083700ca8c135ba9f0f132930d4e8                      8686
# 1463   a40096fc0a3862e9e12bc55b5f8e6ab2                     20561
# 1607   b8b3c435a58aebd788a477bed8342910                     95585
# 2811   66980c3775537536f77b434d74e520f5                     30290
# 3198   788313d21c3507fe890921f6e17aa679                     11070
# ...                                 ...                       ...
# 99324  8bab3162259edfaadd1ea2e1fe7f58dc                     31565
# 99327  12ab9334b1240d6d037f2b0102a49571                     38050
# 99336  0ee57f62666561b72f2ceacad0230cbf                      9530
# 99353  0ceb502fc33a2ad327b08288c5310e2e                     29134
# 99406  5cbfdb85ec130898108b32c50d619c39                     74980
#
#               customer_city customer_state
# 679                  suzano             SP
# 1463         rio de janeiro             RJ
# ...

# %%
# checking for duplicate value.
customers.drop_duplicates(subset='customer_id', keep='first')
# Out:
#                             customer_id  customer_zip_code_prefix  \
# 0      861eff4711a542e4b93843c6dd7febb0                     14409
# 1      290c77bc529b7ac935b93aa66c333dc3                      9790
# 2      060e732b5b29e8181a18229c7b0b2b5e                      1151
# 3      259dac757896d24d7702b9acbbff3f3c                      8775
# 4      345ecd01c38d18a9036ed96c73b8d066                     13056
# ...                                 ...                       ...
# 99436  1a29b476fee25c95fbafc67c5ac95cf8                      3937
# 99437  d52a67c98be1cf6a5c84435bd38d095d                      6764
# 99438  e9f50caf99f032f0bf3c55141f019d99                     60115
# 99439  73c2643a0a458b49f58cea58833b192e                     92120
# 99440  84732c5050c01db9b23e19ba39899398                      6703
#
#                customer_city customer_state
# 0                     franca             SP
# 1      sao bernardo do campo             SP
# ...

# %%
99441 - 96096
# Out:
# 3345

# %%
# Dropping duplicate value.
customers.drop_duplicates(subset='customer_id', keep='first', inplace=True)
customers.shape
# Out:
# (96096, 4)

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96096 entries, 0 to 99440
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               96096 non-null  object
#  1   customer_zip_code_prefix  96096 non-null  int64
#  2   customer_city             96096 non-null  object
#  3   customer_state            96096 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 3.7+ MB

# %%
payments = pd.read_excel("C://Users//Jaydeep//Downloads//Retail_dataset.xlsx", sheet_name="payments")
payments.shape
# Out:
# (103886, 5)

# %%
payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
payments.isna().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
products = pd.read_excel("C://Users//Jaydeep//Downloads//Retail_dataset.xlsx", sheet_name="products")
products.shape
# Out:
# (32951, 6)

# %%
products.head()
# Out:
#                          product_id product_category_name  product_weight_g  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumery             225.0
# 1  3aa071139cb16b67ca9e5dea641aaa2f                   art            1000.0
# 2  96bd76ec8810374ed1b65e291975717f        sports_leisure             154.0
# 3  cef67bcfe19066a932b7673e239eb23d                  baby             371.0
# 4  9dc1a7de274444849c219cff195d0b71            housewares             625.0
#
#    product_length_cm  product_height_cm  product_width_cm
# 0               16.0               10.0              14.0
# 1               30.0               18.0              20.0
# 2               18.0                9.0              15.0
# 3               26.0                4.0              26.0
# 4               20.0               17.0              13.0

# %%
products.isna().sum().sort_values(ascending=False)
# Out:
# product_category_name    170
# product_width_cm           2
# product_height_cm          2
# product_length_cm          2
# product_weight_g           2
# product_id                 0
# dtype: int64

# %%
products.product_category_name.value_counts()
# Out:
# toys                                 24725
# bed_bath_table                         789
# sports_leisure                         721
# furniture_decor                        687
# health_beauty                          648
#                                      ...
# diapers_and_hygiene                      1
# home_comfort_2                           1
# security_and_services                    1
# furniture_mattress_and_upholstery        1
# fashion_childrens_clothes                1
# Name: product_category_name, Length: 70, dtype: int64

# %%
products.product_category_name.value_counts(normalize=True)*100
# Out:
# toys                                 75.424789
# bed_bath_table                        2.406882
# sports_leisure                        2.199445
# furniture_decor                       2.095726
# health_beauty                         1.976755
#                                        ...
# diapers_and_hygiene                   0.003051
# home_comfort_2                        0.003051
# security_and_services                 0.003051
# furniture_mattress_and_upholstery     0.003051
# fashion_childrens_clothes             0.003051
# Name: product_category_name, Length: 70, dtype: float64

# %%
products.product_category_name.mode()
# Out:
# 0    toys
# dtype: object

# %%
products.product_category_name.fillna(products.product_category_name.mode()[0], inplace=True)

# %%
products.isna().sum().sort_values(ascending=False)
# Out:
# product_width_cm         2
# product_height_cm        2
# product_length_cm        2
# product_weight_g         2
# product_category_name    0
# product_id               0
# dtype: int64

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   product_category_name  32951 non-null  object
#  2   product_weight_g       32949 non-null  float64
#  3   product_length_cm      32949 non-null  float64
#  4   product_height_cm      32949 non-null  float64
#  5   product_width_cm       32949 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 1.5+ MB

# %%
# To check the basic statistical details
products.describe()
# Out:
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
sns.boxplot(y = products.product_weight_g)
plt.show()

# %%
sns.boxplot(y = products.product_length_cm)
plt.show()

# %%
sns.boxplot(y = products.product_height_cm)
plt.show()

# %%
sns.boxplot(y = products.product_width_cm)
plt.show()

# %%
products.product_weight_g.median()
# Out:
# 700.0

# %%
products.product_length_cm.median()
# Out:
# 25.0

# %%
products.product_height_cm.mean()
# Out:
# 16.937661234028347

# %%
products.product_width_cm.mean()
# Out:
# 23.196728277034204

# %%
products.product_weight_g.fillna(products.product_weight_g.median(), inplace=True)
products.product_length_cm.fillna(products.product_length_cm.median(), inplace=True)
products.product_height_cm.fillna(products.product_height_cm.mean(), inplace=True)
products.product_width_cm.fillna(products.product_width_cm.mean(), inplace=True)

# %%
products.isna().sum().sort_values(ascending=False)
# Out:
# product_width_cm         0
# product_height_cm        0
# product_length_cm        0
# product_weight_g         0
# product_category_name    0
# product_id               0
# dtype: int64

# %% [markdown]
# ### Hence, EDA has been completed and now performing Market Basket Analysis on the dataset.

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32951 non-null  object
#  1   product_category_name  32951 non-null  object
#  2   product_weight_g       32951 non-null  float64
#  3   product_length_cm      32951 non-null  float64
#  4   product_height_cm      32951 non-null  float64
#  5   product_width_cm       32951 non-null  float64
# dtypes: float64(4), object(2)
# memory usage: 1.5+ MB

# %%
products.product_category_name.value_counts()
# Out:
# toys                                 24895
# bed_bath_table                         789
# sports_leisure                         721
# furniture_decor                        687
# health_beauty                          648
#                                      ...
# diapers_and_hygiene                      1
# home_comfort_2                           1
# security_and_services                    1
# furniture_mattress_and_upholstery        1
# fashion_childrens_clothes                1
# Name: product_category_name, Length: 70, dtype: int64

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   order_id          112650 non-null  object
#  1   order_item_id     112650 non-null  int64
#  2   product_id        112650 non-null  object
#  3   seller_id         112650 non-null  object
#  4   price             112650 non-null  float64
#  5   shipping_charges  112650 non-null  float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 5.2+ MB

# %%
len(order_items['order_id'].unique())
# Out:
# 98666

# %%
data = order_items.merge(products[['product_id','product_category_name']], on='product_id', how='inner')

# %%
data.shape
# Out:
# (112650, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   order_id               112650 non-null  object
#  1   order_item_id          112650 non-null  int64
#  2   product_id             112650 non-null  object
#  3   seller_id              112650 non-null  object
#  4   price                  112650 non-null  float64
#  5   shipping_charges       112650 non-null  float64
#  6   product_category_name  112650 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.9+ MB

# %%
# Creating a basket for the analysis 
Basket = (data.groupby(['order_id', 'product_category_name'])
          ['order_item_id'].sum().unstack().reset_index().fillna(0).set_index('order_id'))

# %%
Basket
# Out:
# product_category_name             agro_industry_and_commerce  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                         0.0
# 00018f77f2f0320c557190d7a144bdd3                         0.0
# 000229ec398224ef6ca0657da4fc703e                         0.0
# 00024acbcdf0a6daa1e931b038114c75                         0.0
# 00042b26cf59d7ce69dfabb4e55b4fd9                         0.0
# ...                                                      ...
# fffc94f6ce00a00581880bf54a75a037                         0.0
# fffcd46ef2263f404302a634eb57f7eb                         0.0
# fffce4705a9662cd70adb13d4a31832d                         0.0
# fffe18544ffabc95dfada21779c9644f                         0.0
# fffe41c64501cc87c801fd61db3f6244                         0.0
#
# product_category_name             air_conditioning  art  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214               0.0  0.0
# 00018f77f2f0320c557190d7a144bdd3               0.0  0.0
# ...

# %%
# Converting the values to 0 or 1

def encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

Basket_encode = Basket.applymap(encode_units)
Basket_encode
# Out:
# product_category_name             agro_industry_and_commerce  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                           0
# 00018f77f2f0320c557190d7a144bdd3                           0
# 000229ec398224ef6ca0657da4fc703e                           0
# 00024acbcdf0a6daa1e931b038114c75                           0
# 00042b26cf59d7ce69dfabb4e55b4fd9                           0
# ...                                                      ...
# fffc94f6ce00a00581880bf54a75a037                           0
# fffcd46ef2263f404302a634eb57f7eb                           0
# fffce4705a9662cd70adb13d4a31832d                           0
# fffe18544ffabc95dfada21779c9644f                           0
# fffe41c64501cc87c801fd61db3f6244                           0
#
# product_category_name             air_conditioning  art  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                 0    0
# 00018f77f2f0320c557190d7a144bdd3                 0    0
# ...

# %%
# Filter the Basket with the sum of values having >=2

Basket_encode_filter = Basket_encode[(Basket_encode > 0).sum(axis=1) >=2]
Basket_encode_filter
# Out:
# product_category_name             agro_industry_and_commerce  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e                           0
# 00946f674d880be1f188abc10ad7cf46                           0
# 00bcee890eba57a9767c7b5ca12d3a1b                           0
# 01144cadcf64b6427f0a6580a3033220                           0
# 013a98b3a668bcef05b98898177f6923                           0
# ...                                                      ...
# ff632bc583a94f23c59db4cbaa0ba2ab                           0
# ffa466d3e55f98477b7e0da764df3c6c                           0
# ffb9a9cd00c74c11c24aa30b3d78e03b                           0
# ffc16cecff8dc037f60458f28d1c1ba5                           0
# ffd543c2b60842e148a86870dc60e212                           0
#
# product_category_name             air_conditioning  art  \
# order_id
# 00337fe25a3780b3424d9ad7c5a4b35e                 0    0
# 00946f674d880be1f188abc10ad7cf46                 0    0
# ...

# %%
# Importing libraries for performing Market Basket Analysis.

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
frequent_itemsets = apriori(Basket_encode_filter, min_support=0.03, 
                            use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
frequent_itemsets["Length"] = frequent_itemsets['itemsets'].apply(lambda x:len(x))

frequent_itemsets
# Out:
#      support                          itemsets  Length
# 0   0.971604                            (toys)       1
# 1   0.229470                  (bed_bath_table)       1
# 2   0.225633            (toys, bed_bath_table)       2
# 3   0.127398                 (furniture_decor)       1
# 4   0.119724           (toys, furniture_decor)       2
# 5   0.083653           (computers_accessories)       1
# 6   0.079816     (toys, computers_accessories)       2
# 7   0.067536                   (health_beauty)       1
# 8   0.064467             (toys, health_beauty)       2
# 9   0.057559                   (watches_gifts)       1
# 10  0.056025             (toys, watches_gifts)       2
# 11  0.054490                  (sports_leisure)       1
# 12  0.052955                      (housewares)       1
# 13  0.048350                (toys, housewares)       2
# 14  0.047583            (toys, sports_leisure)       2
# 15  0.041443                    (garden_tools)       1
# ...

# %%
rules = association_rules(frequent_itemsets, metric='lift', 
                          min_threshold = 1).sort_values('lift', ascending=False).reset_index(drop=True)
rules
# Out:
#                   antecedents                 consequents  antecedent support  \
# 0                      (toys)            (bed_bath_table)            0.971604
# 1            (bed_bath_table)                      (toys)            0.229470
# 2                      (toys)  (fashion_bags_accessories)            0.971604
# 3  (fashion_bags_accessories)                      (toys)            0.033001
# 4                      (toys)                      (auto)            0.971604
# 5                      (auto)                      (toys)            0.031466
# 6                      (toys)             (watches_gifts)            0.971604
# 7             (watches_gifts)                      (toys)            0.057559
#
#    consequent support   support  confidence      lift  leverage  conviction
# 0            0.229470  0.225633    0.232227  1.012015  0.002679    1.003591
# 1            0.971604  0.225633    0.983278  1.012015  0.002679    1.698081
# ...

# %%
# Filter the Basket with the sum of values having >=3

Basket_encode_filter_1 = Basket_encode[(Basket_encode > 0).sum(axis=1) >=3]
Basket_encode_filter_1
# Out:
# product_category_name             agro_industry_and_commerce  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae                           0
# 1c4a92d82c1b0dec18bef12da3fa7756                           0
# 43443d5fff4b94d98df1ad41af13d302                           0
# 5337d26d14027f547caacb7fee230f81                           0
# 91be51c856a90d7efe86cf9d082d6ae3                           0
# a98012aa8c697f2bcff9f8c2183e0f2b                           0
# c6a7876557e3e3e31f229852dfa4f5c3                           0
# d4bec1a24c97bd17be18d77297a0f6a0                           0
# ddb33b0aa1ca6227208f0ca0564f0696                           0
# f1e2b7376f89e974ba81956b133ef935                           0
#
# product_category_name             air_conditioning  art  \
# order_id
# 0a77b770428bccbea7f9dbf8aec5d6ae                 0    0
# 1c4a92d82c1b0dec18bef12da3fa7756                 0    0
# 43443d5fff4b94d98df1ad41af13d302                 0    0
# ...

# %%
frequent_itemsets_1 = apriori(Basket_encode_filter_1, min_support=0.03, 
                            use_colnames=True).sort_values('support', ascending=False).reset_index(drop=True)
frequent_itemsets_1["Length"] = frequent_itemsets_1['itemsets'].apply(lambda x:len(x))

frequent_itemsets_1
# Out:
#     support                                          itemsets  Length
# 0       1.0                                            (toys)       1
# 1       0.5                                  (bed_bath_table)       1
# 2       0.5                            (toys, bed_bath_table)       2
# 3       0.4                                 (furniture_decor)       1
# 4       0.4                           (toys, furniture_decor)       2
# 5       0.2                                    (garden_tools)       1
# 6       0.2                           (computers_accessories)       1
# 7       0.2                              (toys, garden_tools)       2
# 8       0.2                     (toys, computers_accessories)       2
# 9       0.2           (toys, bed_bath_table, furniture_decor)       3
# 10      0.2                 (bed_bath_table, furniture_decor)       2
# 11      0.1                (toys, bed_bath_table, housewares)       3
# ...

# %%
rules_1 = association_rules(frequent_itemsets_1, metric='lift', 
                          min_threshold = 1).sort_values('lift', ascending=False).reset_index(drop=True)
rules_1.head(20)
# Out:
#                       antecedents                    consequents  \
# 0               (toys, telephony)                   (cine_photo)
# 1                     (telephony)                   (cine_photo)
# 2                    (cine_photo)              (toys, telephony)
# 3                     (telephony)             (toys, cine_photo)
# 4              (toys, cine_photo)                    (telephony)
# 5                    (cine_photo)                    (telephony)
# 6         (computers_accessories)      (toys, home_construction)
# 7             (home_construction)        (computers_accessories)
# 8       (toys, home_construction)        (computers_accessories)
# 9   (toys, computers_accessories)            (home_construction)
# 10        (computers_accessories)            (home_construction)
# 11            (home_construction)  (toys, computers_accessories)
# 12              (furniture_decor)            (electronics, toys)
# ...
